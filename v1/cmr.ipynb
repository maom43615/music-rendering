# %% [markdown]
# # 🎹 MIDI to Video Renderer (Fixed Version)
#
# This notebook fixes the `moviepy` error by installing the compatible version (1.0.3).
#
# ### 🚀 Instructions:
# 1.  **Run the Setup Cell** below (click the Play button ▶️).
# 2.  **Upload your MIDI file** to the `Files` sidebar on the left.
# 3.  **Run the Render Cell**, changing `song.mid` to your file name.

# %%
# @title 1. Setup Environment (Fixed)
import os

print("⏳ Installing system tools...")
# !sudo apt-get update -qq
# !sudo apt-get install -y fluidsynth ffmpeg > /dev/null

print("⏳ Installing Python libraries (forcing moviepy 1.0.3)...")
# THE FIX IS HERE: We force version 1.0.3 to prevent the import error
# !pip install mido opencv-python numpy tqdm "moviepy==1.0.3" > /dev/null

if not os.path.exists("midi2video"):
    print("⬇️ Cloning repository...")
    # !git clone https://github.com/ablomer/midi2video.git
    
    # Fix font bug
    # !sed -i 's/arial.ttf/DejaVuSans.ttf/g' midi2video/midi2video.py
    
    # Fix imageio dependency bug (sometimes needed for moviepy 1.x)
    # !pip install imageio==2.4.1 > /dev/null

print("✅ SETUP COMPLETE! You can now render videos.")

# %%
# @title 2. Render Video
# ---------------------------------------------------------
# REPLACE 'song.mid' WITH YOUR EXACT FILENAME BELOW:
midi_filename = "song.mid"
output_filename = "video.mp4"
# ---------------------------------------------------------

import os
if not os.path.exists(midi_filename):
    print(f"❌ ERROR: File '{midi_filename}' not found. Did you upload it to the sidebar?")
else:
    print(f"🎬 Starting render for {midi_filename}...")
    # !python midi2video/midi2video.py --midi "{midi_filename}" --output "{output_filename}"
    print(f"✅ Done! Check the sidebar for {output_filename}. Right-click to download.")
